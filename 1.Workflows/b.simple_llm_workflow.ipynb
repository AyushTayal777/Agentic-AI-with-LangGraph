# %%
from langgraph.graph import StateGraph,START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model=ChatGoogleGenerativeAI(model='gemini-3.6-flash')

# %%
# create a state

class LLMState(TypedDict):
    question:str
    answer:str

# %%
def llm_qa(state:LLMState)->LLMState:
    # extract the question from state
    
    question=state['question']

    # form a prompt
    
    prompt=f'Answer the following question {question}'

    # ask the question to the LLM

    answer=model.invoke(prompt).text

    # update the asnwer in the state

    state['answer']=answer

    return state

# %%
# create our graph
graph=StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa',llm_qa)

# add edges
graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)

# compile
workflow=graph.compile()

# %%
# execute

initial_state={'question': 'how far is moon from the earth'}

final_state=workflow.invoke(initial_state)
print(final_state)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# {'question': 'how far is moon from the earth', 'answer': "On average, the Moon is about **384,400 kilometers (238,855 miles)** away from Earth. \n\nHowever, because the Moon's orbit around Earth is elliptical (egg-shaped) rather than a perfect circle, this distance changes throughout the month:\n\n* **Closest point (Perigee):** About **363,300 km (225,623 miles)**\n* **Farthest point (Apogee):** About **405,500 km (251,966 miles)**\n\n---\n\n### A Few Fun Ways to Visualize the Distance:\n* **Light speed:** Light (or a radio signal) takes about **1.3 seconds** to travel from Earth to the Moon.\n* **Fitting the planets:** You could fit all seven other planets in our solar system side-by-side in the space between Earth and the Moon, with room to spare!\n* **Road trip:** If you could drive a car to the Moon at 60 mph (100 km/h), it would take you almost **6 months** of continuous driving to get there."}
