# %%
from langgraph.graph import StateGraph,START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model=ChatGoogleGenerativeAI(model='gemini-3.6-flash')

# %%
# create a state

class LLMState(TypedDict):
    question:str
    answer:str

# %%
def llm_qa(state:LLMState)->LLMState:
    # extract the question from state
    
    question=state['question']

    # form a prompt
    
    prompt=f'Answer the following question {question}'

    # ask the question to the LLM

    answer=model.invoke(prompt).text

    # update the asnwer in the state

    state['answer']=answer

    return state

# %%
# create our graph
graph=StateGraph(LLMState)

# add nodes
graph.add_node('llm_qa',llm_qa)

# add edges
graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)

# compile
workflow=graph.compile()

# %%
# execute

initial_state={'question': 'how far is moon from the mars'}

final_state=workflow.invoke(initial_state)
print(final_state)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# {'question': 'how far is moon from the mars', 'answer': 'Because both the Earth (with the Moon) and Mars are constantly orbiting the Sun at different speeds and distances, **the distance between the Moon and Mars is always changing.** \n\nSince the Moon is relatively close to Earth, the distance from the Moon to Mars is essentially the same as the distance from Earth to Mars.\n\nHere are the key distances:\n\n* **Average Distance:** About **225 million kilometers** (140 million miles).\n* **Closest Possible Distance:** About **54.6 million kilometers** (33.9 million miles). This happens when Mars is at its closest point to the Sun and Earth/Moon pass directly between Mars and the Sun.\n* **Farthest Possible Distance:** About **401 million kilometers** (250 million miles). This happens when Earth/Moon and Mars are on exact opposite sides of the Sun.\n\n### How long does it take to travel that distance?\n* **At the speed of light:** Radio signals take between **3 minutes** (at closest approach) and **22 minutes** (at farthest distance) to travel between the Moon and Mars.\n* **By spacecraft:** A typical mission to Mars currently takes about **6 to 8 months** to travel the distance, depending on planetary alignment.'}
